# %%
# %pylab inline


pylab.rcParams['figure.figsize'] = (14.0, 10.0)

import numpy as np
import matplotlib.pyplot as plt

# Get the IMU signals from a file
def getSigs(fileName):
    fin = open(fileName)

    lines = fin.readlines()
    fin.close()
    
    res = []
    for str in lines:
        tmp = str.split()
        tmp = map(eval, tmp)
        res.append(tmp)

    res_array = np.array(res)
    res_array = res_array[10:, :]
    correctBias(res_array)
    
    return res_array



def correctBias(array):
    #still_array = getSigs('../data/still_normal.txt')
    
    
    # TODO, the parameters may need be adjusted when in different posture
    # The bias of gyr_x, gyr_y, gyr_z, statistics from still_normal.txt
    gyr_bias = np.array([-0.01568079, 0.02071555, 0.0186753 ])
    array[:, 3:6] = array[:, 3:6] - gyr_bias
    

def calOrientationAngle(mag_xyz):
    x = mag_xyz[:,0]
    y = mag_xyz[:,1]
    z = mag_xyz[:,2]
    
    #float azimuth = atan2(  (float)(data->magnetic.x ),(float)(data->magnetic.y) )
    azimuth = np.arctan2(x, z)*180/np.pi
    #ind = (azimuth < 0)
    #azimuth[ind] = 360 + azimuth[ind]
    #azimuth = 360 - azimuth
    
    print azimuth
    
    
    #orientation.pitch = atan2( (float)(data->magnetic.y ),(float)(data->magnetic.z)    
#)*180/PI;  
    pitch = np.arctan2(z, y)*180/np.pi
    #print pitch
    
    
    roll = np.arctan2(x, y)*180/np.pi
    #print roll
    
    plt.plot(x, 'r')
    plt.plot(y, 'g')
    plt.plot(z, 'b')
    plt.show()
    
    
if __name__=='__main__':
    dir = '../data/'
    fileName = dir + 'orientation_south.txt'
    
    res_array = getSigs(fileName)
    calOrientationAngle(res_array[:, 6:])
# Out:
# Populating the interactive namespace from numpy and matplotlib
# [ 21.50143432  12.72435569  12.52880771  14.03624347  16.38954033
#   14.93141718  14.74356284  28.73979529  12.52880771  19.53665494
#   14.03624347  18.43494882  18.43494882  20.55604522  22.75097634
#   25.01689348  24.14554196  18.43494882  23.62937773   7.59464337
#   12.52880771  19.53665494  18.43494882  10.71312302  22.38013505
#   29.35775354  20.55604522  14.03624347  11.30993247  19.53665494
#   28.30075577  17.2414594   22.75097634  19.65382406  28.73979529
#   10.0079798   22.16634582  15.2551187   14.93141718  20.77225468
#   13.24051992  22.38013505  11.30993247  14.03624347  16.38954033
#   11.97613244  10.0079798   24.14554196  12.99461679  12.72435569
#   10.0079798   11.30993247  11.88865804  22.75097634  21.50143432
#   22.16634582  10.0079798   14.03624347  17.44718842  14.42077313
#   13.57043439  19.44003483  14.42077313  12.52880771  24.44395478
#   11.30993247  20.55604522  13.57043439  19.53665494  17.35402464
#   21.80140949  17.35402464  16.38954033  20.55604522  24.77514057
#   13.67130713   8.13010235  13.67130713  21.80140949  21.50143432
